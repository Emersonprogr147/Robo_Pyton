# %%
# !pip install selenium
# Out:
# ...
#   Obtaining dependency information for selenium from https://files.pythonhosted.org/packages/dc/72/96b5afa16908f9abc7c24b70adfd3a46c9740eb728ddfeab28379e38eaf9/selenium-4.16.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for trio~=0.17 from https://files.pythonhosted.org/packages/14/fb/9299cf74953f473a15accfdbe2c15218e766bae8c796f2567c83bae03e98/trio-0.24.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for trio-websocket~=0.9 from https://files.pythonhosted.org/packages/48/be/a9ae5f50cad5b6f85bd2574c2c923730098530096e170c1ce7452394d7aa/trio_websocket-0.11.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for outcome from https://files.pythonhosted.org/packages/55/8b/5ab7257531a5d830fc8000c476e63c935488d74609b50f9384a643ec0a62/outcome-1.3.0.post0-py2.py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#      ----------------------------------- ---- 51.2/58.3 kB 2.6 MB/s eta 0:00:01
# ...

# %%
from selenium import webdriver


abrirNavegador = webdriver.Edge()


abrirNavegador.get("https://hoeperscredito.sharepoint.com/sites//GC-TRANSF/Documentos%20Compartilhados/Forms/AllItems.aspx?id=%2Fsites%2FGC%2DTRANSF%2FDocumentos%20Compartilhados%2FAssessorias%2FGEN%2FArquivos%20Di%C3%A1rios&viewid=b95da5b6%2Ddb40%2D417c%2Da9cf%2Db89e236fcad5")

# %%
#IMPORTANDO O SELENIUM PARA TRABALHAR COM PAGINAS  DA WEB 
from selenium import webdriver as opcoes_selenium
from selenium.webdriver.common.keys  import Keys 


#IMPORTANDO A BIBLIOTECA DO PYAUTOGUI 
import pyautogui as tempoPausaComputador 
import pyautogui as posicaoMouse

# USANDING  THE  BY  PARA WORKED WITH UPDATE MORE NEW RECENT 
from selenium.webdriver.common.by import By 


#PASSANDO AS AUTORIZAÇÃO  DE CONFIGURAÇÃO DE ACESSO AO FIREFOX 
meuNavegador = opcoes_selenium.Edge()
meuNavegador.get("https://sol.ativossa.com.br/WsExtCob/pages/index.xhtml")

#AGUARDA 4 SEGUNDOS PARA O COMPUTADOR PROCESSAR 
tempoPausaComputador.sleep(2)

meuNavegador.find_element(By.NAME,"j_username").send_keys("bruna.oliani234")

meuNavegador.find_element(By.NAME,"j_password").send_keys("Ativos@9711")


#AGUARDA 4 SEGUNDOS PARA O COMPUTADOR PROCESSAR 
tempoPausaComputador.sleep(2)

meuNavegador.find_element(By.NAME,"j_idt20").send_keys(Keys.RETURN)

tempoPausaComputador.sleep(3)

#POSIÇÃO  FOR CLICKAR  AND OPEN  THE RELATORIOS
posicaoMouse.moveTo(x=259, y=197)
posicaoMouse.click(x=259, y=197)

tempoPausaComputador.sleep(3)

#POSITION FOR CLICLAR  IN RELATORIOS 

posicaoMouse.moveTo(x=118, y=382)
posicaoMouse.click(x=118, y=382)
#POSITION FOR CLICLAR  IN PAYMENT 
tempoPausaComputador.sleep(2)

posicaoMouse.moveTo(x=126, y=434)
posicaoMouse.click(x=126, y=434)

tempoPausaComputador.sleep(3)

posicaoMouse.moveTo(x=107, y=351)
posicaoMouse.click(x=107, y=351)

tempoPausaComputador.sleep(3)

meuNavegador.find_element(By.NAME,"from_fluxo_parcela:button_input").send_keys("25/01/2024")

tempoPausaComputador.sleep(2)

posicaoMouse.moveTo(x=398, y=353)
posicaoMouse.click(x=398, y=353)

meuNavegador.find_element(By.NAME,"from_fluxo_parcela:button2_input").send_keys("26/01/2024")

tempoPausaComputador.sleep(2)

posicaoMouse.moveTo(x=592, y=341)
posicaoMouse.click(x=592, y=341)

tempoPausaComputador.sleep(2)

#CLICANDO NA OPÇÃO CSV PARA BAIXAR ARQUIVOS 
posicaoMouse.moveTo(x=944, y=429)
posicaoMouse.click(x=944, y=429)
posicaoMouse.click(x=944, y=429)




#POSITION FOR CLICLAR  IN RELATORIOS 

posicaoMouse.moveTo(x=255, y=195)
posicaoMouse.click (x=255, y=195)

#POSITION FOR CLICLAR  IN ACORDO 
tempoPausaComputador.sleep(2)

posicaoMouse.moveTo(x=123, y=509)
posicaoMouse.click(x=123, y=509)

tempoPausaComputador.sleep(2)

#POSITION FOR CLICLAR  IN CAMPO DATE INITIAL 
posicaoMouse.moveTo(x=103, y=350)
posicaoMouse.click(x=103, y=350)

tempoPausaComputador.sleep(3)

meuNavegador.find_element(By.NAME,"from_acordos:button_input").send_keys("24/01/2024")

tempoPausaComputador.sleep(2)

posicaoMouse.moveTo(x=398, y=350)
posicaoMouse.click(x=398, y=350)

meuNavegador.find_element(By.NAME,"from_acordos:button2_input").send_keys("25/01/2024")

tempoPausaComputador.sleep(3)

#POSITION FOR CLICKAR NA OPÇÃO SEND(ENVIAR)

posicaoMouse.moveTo(x=594, y=341)
posicaoMouse.click(x=594, y=341)

tempoPausaComputador.sleep(3)

#CLICANDO NA OPÇÃO PARA BAIXAR ARQUIVOS 
posicaoMouse.moveTo(x=925, y=429)
posicaoMouse.click(x=925, y=429)
tempoPausaComputador.sleep(3)

#CLICANDO FOR CLOSE THE PAGE 


posicaoMouse.moveTo(x=1027, y=23)
posicaoMouse.click(x=1027, y=23)
